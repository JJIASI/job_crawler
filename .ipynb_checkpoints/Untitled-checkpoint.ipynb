# %%
import pymongo
client = pymongo.MongoClient(host='localhost', port=27017)

# %%
collection = client.job_data.job_data

# %%
cursor = collection.find({'sourceweb':'104人力銀行'})
data = [d for d in cursor]

# %%
data
# Out:
# [{'_id': ObjectId('5cd558edb6e807040bfe2631'),
#   'jobname': 'GoLang Developer',
#   'jobsalary': 40000,
#   'jobindcat': '電腦軟體服務業',
#   'jobdate': datetime.datetime(2019, 5, 9, 0, 0),
#   'jobcompany': '皆凱科技有限公司',
#   'jobexp': '3年以上',
#   'jobedu': '專科',
#   'jobarea': '台北市內湖區',
#   'jobapply': 1,
#   'sourceweb': '104人力銀行'},
#  {'_id': ObjectId('5cd558edb6e807040bfe2632'),
#   'jobname': 'Backend Developer (golang)',
#   'jobsalary': 40000,
#   'jobindcat': '電腦及其週邊設備製造業',
#   'jobdate': datetime.datetime(2019, 5, 9, 0, 0),
#   'jobcompany': '伍豐科技股份有限公司',
#   'jobexp': '1年以上',
#   'jobedu': '專科',
#   'jobarea': '新北市汐止區',
#   'jobapply': 1,
#   'sourceweb': '104人力銀行'},
#  {'_id': ObjectId('5cd558edb6e807040bfe2633'),
#   'jobname': 'CI- Backend GoLang Developer',
#   'jobsalary': 40000,
#   'jobindcat': '電腦軟體服務業',
#   'jobdate': datetime.datetime(2019, 5, 3, 0, 0),
#   'jobcompany': '訊真科技股份有限公司',
#   'jobexp': '1年以上',
#   'jobedu': '大學',
#   'jobarea': '台北市大安區',
#   'jobapply': 1,
# ...
